# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes= True)

# %%
mmr= pd.read_csv('mmr edited.csv')

# %%
mmr.head()
# Out:
#   ISO Code       Country  2010  2011  2012  2013  2014  2015  2016  2017  \
# 0      DZA       Algeria   119   117   117   115   116   116   115   114
# 1      AGO        Angola   431   395   359   326   300   281   269   258
# 2      BEN         Benin   486   480   471   464   458   450   441   432
# 3      BWA      Botswana   209   203   189   179   176   170   164   160
# 4      BFA  Burkina Faso   410   401   393   385   377   369   362   353
#
#    2018  2019  2020
# 0   114   113   112
# 1   251   246   241
# 2   421   408   397
# 3   156   151   144
# 4   343   331   320

# %%
mmr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ISO Code  52 non-null     object
#  1   Country   52 non-null     object
#  2   2010      52 non-null     int64
#  3   2011      52 non-null     int64
#  4   2012      52 non-null     int64
#  5   2013      52 non-null     int64
#  6   2014      52 non-null     int64
#  7   2015      52 non-null     int64
#  8   2016      52 non-null     int64
#  9   2017      52 non-null     int64
#  10  2018      52 non-null     int64
#  11  2019      52 non-null     int64
#  12  2020      52 non-null     int64
# dtypes: int64(11), object(2)
# memory usage: 5.4+ KB

# %%
import numpy as np
import matplotlib.pyplot as plt
sns.barplot(mmr['ISO Code'], mmr['2010'])
N = 52


plt.xticks(range(N)) # add loads of ticks
plt.grid()

plt.gca().margins(x=0)
plt.gcf().canvas.draw()
tl = plt.gca().get_xticklabels()
maxsize = max([t.get_window_extent().width for t in tl])
m = 0.2 # inch margin
s = maxsize/plt.gcf().dpi*N+2*m
margin = m/plt.gcf().get_size_inches()[0]

plt.gcf().subplots_adjust(left=margin, right=1.-margin)
plt.gcf().set_size_inches(s, plt.gcf().get_size_inches()[1])
plt.title('MATERNAL MORTALITY RATIO FOR 2010')


plt.show()
# Out:
# C:\Users\Damisi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt
sns.barplot(mmr['ISO Code'], mmr['2011'])
N = 52


plt.xticks(range(N)) # add loads of ticks
plt.grid()

plt.gca().margins(x=0)
plt.gcf().canvas.draw()
tl = plt.gca().get_xticklabels()
maxsize = max([t.get_window_extent().width for t in tl])
m = 0.2 # inch margin
s = maxsize/plt.gcf().dpi*N+2*m
margin = m/plt.gcf().get_size_inches()[0]

plt.gcf().subplots_adjust(left=margin, right=1.-margin)
plt.gcf().set_size_inches(s, plt.gcf().get_size_inches()[1])
plt.title('MATERNAL MORTALITY RATIO FOR 2011')

plt.show()
# Out:
# C:\Users\Damisi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt
sns.barplot(mmr['ISO Code'], mmr['2012'])
N = 52


plt.xticks(range(N)) # add loads of ticks
plt.grid()

plt.gca().margins(x=0)
plt.gcf().canvas.draw()
tl = plt.gca().get_xticklabels()
maxsize = max([t.get_window_extent().width for t in tl])
m = 0.2 # inch margin
s = maxsize/plt.gcf().dpi*N+2*m
margin = m/plt.gcf().get_size_inches()[0]

plt.gcf().subplots_adjust(left=margin, right=1.-margin)
plt.gcf().set_size_inches(s, plt.gcf().get_size_inches()[1])
plt.title('MATERNAL MORTALITY RATIO FOR 2012')


plt.show()
# Out:
# C:\Users\Damisi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt
sns.barplot(mmr['ISO Code'], mmr['2013'])
N = 52


plt.xticks(range(N)) # add loads of ticks
plt.grid()

plt.gca().margins(x=0)
plt.gcf().canvas.draw()
tl = plt.gca().get_xticklabels()
maxsize = max([t.get_window_extent().width for t in tl])
m = 0.2 # inch margin
s = maxsize/plt.gcf().dpi*N+2*m
margin = m/plt.gcf().get_size_inches()[0]

plt.gcf().subplots_adjust(left=margin, right=1.-margin)
plt.gcf().set_size_inches(s, plt.gcf().get_size_inches()[1])
plt.title('MATERNAL MORTALITY RATIO FOR 2013')


plt.show()
# Out:
# C:\Users\Damisi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt
sns.barplot(mmr['ISO Code'], mmr['2014'])
N = 52


plt.xticks(range(N)) # add loads of ticks
plt.grid()

plt.gca().margins(x=0)
plt.gcf().canvas.draw()
tl = plt.gca().get_xticklabels()
maxsize = max([t.get_window_extent().width for t in tl])
m = 0.2 # inch margin
s = maxsize/plt.gcf().dpi*N+2*m
margin = m/plt.gcf().get_size_inches()[0]

plt.gcf().subplots_adjust(left=margin, right=1.-margin)
plt.gcf().set_size_inches(s, plt.gcf().get_size_inches()[1])
plt.title('MATERNAL MORTALITY RATIO FOR 2014')

plt.show()
# Out:
# C:\Users\Damisi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt
sns.barplot(mmr['ISO Code'], mmr['2015'])
N = 52


plt.xticks(range(N)) # add loads of ticks
plt.grid()

plt.gca().margins(x=0)
plt.gcf().canvas.draw()
tl = plt.gca().get_xticklabels()
maxsize = max([t.get_window_extent().width for t in tl])
m = 0.2 # inch margin
s = maxsize/plt.gcf().dpi*N+2*m
margin = m/plt.gcf().get_size_inches()[0]

plt.gcf().subplots_adjust(left=margin, right=1.-margin)
plt.gcf().set_size_inches(s, plt.gcf().get_size_inches()[1])
plt.title('MATERNAL MORTALITY RATIO FOR 2015')


plt.show()
# Out:
# C:\Users\Damisi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt
sns.barplot(mmr['ISO Code'], mmr['2016'])
N = 52


plt.xticks(range(N)) # add loads of ticks
plt.grid()

plt.gca().margins(x=0)
plt.gcf().canvas.draw()
tl = plt.gca().get_xticklabels()
maxsize = max([t.get_window_extent().width for t in tl])
m = 0.2 # inch margin
s = maxsize/plt.gcf().dpi*N+2*m
margin = m/plt.gcf().get_size_inches()[0]

plt.gcf().subplots_adjust(left=margin, right=1.-margin)
plt.gcf().set_size_inches(s, plt.gcf().get_size_inches()[1])
plt.title('MATERNAL MORTALITY RATIO FOR 2016')


plt.show()
# Out:
# C:\Users\Damisi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt
sns.barplot(mmr['ISO Code'], mmr['2017'])
N = 52


plt.xticks(range(N)) # add loads of ticks
plt.grid()

plt.gca().margins(x=0)
plt.gcf().canvas.draw()
tl = plt.gca().get_xticklabels()
maxsize = max([t.get_window_extent().width for t in tl])
m = 0.2 # inch margin
s = maxsize/plt.gcf().dpi*N+2*m
margin = m/plt.gcf().get_size_inches()[0]

plt.gcf().subplots_adjust(left=margin, right=1.-margin)
plt.gcf().set_size_inches(s, plt.gcf().get_size_inches()[1])
plt.title('MATERNAL MORTALITY RATIO FOR 2017')


plt.show()
# Out:
# C:\Users\Damisi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt
sns.barplot(mmr['ISO Code'], mmr['2018'])
N = 52


plt.xticks(range(N)) # add loads of ticks
plt.grid()

plt.gca().margins(x=0)
plt.gcf().canvas.draw()
tl = plt.gca().get_xticklabels()
maxsize = max([t.get_window_extent().width for t in tl])
m = 0.2 # inch margin
s = maxsize/plt.gcf().dpi*N+2*m
margin = m/plt.gcf().get_size_inches()[0]

plt.gcf().subplots_adjust(left=margin, right=1.-margin)
plt.gcf().set_size_inches(s, plt.gcf().get_size_inches()[1])
plt.title('MATERNAL MORTALITY RATIO FOR 2018')


plt.show()
# Out:
# C:\Users\Damisi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt
sns.barplot(mmr['ISO Code'], mmr['2019'])
N = 52


plt.xticks(range(N)) # add loads of ticks
plt.grid()

plt.gca().margins(x=0)
plt.gcf().canvas.draw()
tl = plt.gca().get_xticklabels()
maxsize = max([t.get_window_extent().width for t in tl])
m = 0.2 # inch margin
s = maxsize/plt.gcf().dpi*N+2*m
margin = m/plt.gcf().get_size_inches()[0]

plt.gcf().subplots_adjust(left=margin, right=1.-margin)
plt.gcf().set_size_inches(s, plt.gcf().get_size_inches()[1])
plt.title('MATERNAL MORTALITY RATIO FOR 2019')


plt.show()
# Out:
# C:\Users\Damisi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt
sns.barplot(mmr['ISO Code'], mmr['2020'])
N = 52


plt.xticks(range(N)) # add loads of ticks
plt.grid()

plt.gca().margins(x=0)
plt.gcf().canvas.draw()
tl = plt.gca().get_xticklabels()
maxsize = max([t.get_window_extent().width for t in tl])
m = 0.2 # inch margin
s = maxsize/plt.gcf().dpi*N+2*m
margin = m/plt.gcf().get_size_inches()[0]

plt.gcf().subplots_adjust(left=margin, right=1.-margin)
plt.gcf().set_size_inches(s, plt.gcf().get_size_inches()[1])
plt.title('MATERNAL MORTALITY RATIO FOR 2020')

plt.show()
# Out:
# C:\Users\Damisi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import pandas as pd
df = pd.read_csv ('mmr edited.csv') 

# block 1 - standard deviation
std1 = df['2010'].std()
std2 = df['2011'].std()
std3 = df['2012'].std()
std4 = df['2013'].std()
std5 = df['2014'].std()
std6 = df['2015'].std()
std7 = df['2016'].std()
std8 = df['2017'].std()
std9 = df['2018'].std()
std10 = df['2019'].std()
std11 = df['2020'].std()
print ('Standard deviation of 2010 ' + str(std1))
print ('Standard deviation of 2011 ' + str(std2))
print ('Standard deviation of 2012 ' + str(std3))
print ('Standard deviation of 2013 ' + str(std4))
print ('Standard deviation of 2014 ' + str(std5))
print ('Standard deviation of 2015 ' + str(std6))
print ('Standard deviation of 2016 ' + str(std7))
print ('Standard deviation of 2017 ' + str(std8))
print ('Standard deviation of 2018 ' + str(std9))
print ('Standard deviation of 2019 ' + str(std10))
print ('Standard deviation of 2020 ' + str(std11))
# Out:
# Standard deviation of 2010 340.59034898543604
# Standard deviation of 2011 328.19549766990923
# Standard deviation of 2012 316.7137031431901
# Standard deviation of 2013 305.5355928393685
# Standard deviation of 2014 297.3032658758603
# Standard deviation of 2015 291.680570235301
# Standard deviation of 2016 291.70170291611754
# Standard deviation of 2017 291.11572118690526
# Standard deviation of 2018 283.7143868721683
# Standard deviation of 2019 277.80079766354845
# Standard deviation of 2020 273.8806005056461

# %%
col = ['2010','2011','2012','2013','2014','2015','2016','2017','2018','2018','2019','2020']


plt.bar(col,mmr[col].mean(), color='b')
plt.xlabel('years')
plt.ylabel('mean')
plt.title('Mean MMR')
# Out:
# Text(0.5, 1.0, 'Mean MMR')

# %%
plt.bar(col,mmr[col].std(), color='g')
plt.xlabel('years')
plt.ylabel('standard deviation')
plt.title('Standard deviation MMR')
# Out:
# Text(0.5, 1.0, 'Standard deviation MMR')

# %%
plt.bar(col,mmr[col].median(), color='y')
plt.xlabel('years')
plt.ylabel('Median')
plt.title('Median MMR')
# Out:
# Text(0.5, 1.0, 'Median MMR')
